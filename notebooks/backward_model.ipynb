# %%
import sys

sys.path.append('/home/ajliang/search/search')

# %%
import argparse
import torch

from utils.common_utils import load_model
from map2map.map2map.data.fields import FieldDataset

# %%
"""Load Dataset"""
device = torch.device("cpu")

args = argparse.Namespace(
    init_input_path="/user_data/ajliang/Linear/val/LH0045/4/dis.npy",
    style_path="/user_data/ajliang/Linear/val/LH0045/4/params.npy",
    target_output_path="/user_data/ajliang/Nonlinear/val/LH0045/4/dis.npy",
    load_backward_model_state="/home/ajliang/search/model_weights/backward_model.pt",
    verbose=False,
    dropout_prob=0.0,
)

forward_dataset = FieldDataset(
    style_pattern=args.style_path,
    in_patterns=[args.init_input_path],
    tgt_patterns=[args.target_output_path],
    in_norms=['cosmology.dis'],
    tgt_norms=None,
    callback_at='/home/ajliang/search/search/map2map',
    augment=True,
    aug_shift=16,
    aug_add=None,
    aug_mul=None,
    crop=40,
    crop_start=None,
    crop_stop=None,
    crop_step=40,
    in_pad=48,
    tgt_pad=0,
    scale_factor=1
)

args.style_size = forward_dataset.style_size
args.in_chan = forward_dataset.in_chan
args.out_chan = forward_dataset.tgt_chan
backward_model = load_model(args, device=device, path_to_model_state=args.load_backward_model_state)

# style: torch.Tensor = forward_dataset[len(forward_dataset) // 2]['style']
# style = style.unsqueeze(0) # add batch dimension

forward_target: torch.Tensor = forward_dataset[len(forward_dataset) // 2]['target']
forward_target = forward_target.unsqueeze(0) # add batch dimension

backward_dataset = FieldDataset(
    style_pattern=args.style_path,
    in_patterns=[args.target_output_path],
    tgt_patterns=[args.init_input_path],
    in_norms=['cosmology.dis'],
    tgt_norms=None,
    callback_at='/home/ajliang/search/search/map2map',
    augment=True,
    aug_shift=16,
    aug_add=None,
    aug_mul=None,
    crop=40,
    crop_start=None,
    crop_stop=None,
    crop_step=40,
    in_pad=48,
    tgt_pad=0,
    scale_factor=1
)

backward_target = backward_dataset[len(backward_dataset) // 2]['input']
# add batch dimension
backward_target = backward_target.unsqueeze(0)
style = backward_dataset[len(backward_dataset) // 2]['style']
# Out:
# Loaded model from /home/ajliang/search/model_weights/backward_model.pt, which was trained for 128 epochs.

# %%
with torch.no_grad():
    init_input = backward_model(backward_target, style)

# %%
init_input
# Out:
# tensor([[[[[-7.9128e-01, -4.3660e-01, -2.4280e-02,  ..., -1.0026e+00,
#             -8.4105e-01, -6.4334e-01],
#            [-7.0180e-01, -3.9467e-01, -5.3336e-02,  ..., -1.1552e+00,
#             -7.8313e-01, -5.7744e-01],
#            [-7.1527e-01, -5.6878e-01, -2.4257e-01,  ..., -1.1448e+00,
#             -7.5055e-01, -6.9462e-01],
#            ...,
#            [ 3.9452e-01,  4.7716e-01,  4.5620e-01,  ..., -9.0856e-01,
#             -1.1139e+00, -9.2768e-01],
#            [ 8.2244e-02,  2.9419e-01,  3.6302e-01,  ..., -8.3037e-01,
#             -8.4866e-01, -7.5762e-01],
#            [ 6.7014e-02,  1.5664e-01,  1.8783e-01,  ..., -9.7690e-01,
#             -9.2157e-01, -7.7015e-01]],
#
#           [[-3.7668e-01, -1.7484e-01, -7.2569e-02,  ..., -4.6536e-01,
#             -2.3622e-01, -1.4246e-01],
#            [-3.9614e-01, -3.0241e-01, -2.2620e-01,  ..., -3.3053e-01,
#             -1.5471e-01, -2.0519e-01],
#            [-2.0440e-01, -2.1050e-01, -3.1533e-01,  ..., -4.4198e-01,
#             -2.1157e-01, -3.8453e-01],
#            ...,
#            [ 2.0150e-01,  9.6466e-03,  7.6827e-03,  ..., -3.1978e-01,
#             -2.0490e-01, -4.1505e-01],
#            [ 8.7057e-02, -6.4826e-02, -1.3974e-01,  ..., -2.4860e-01,
#             -2.7929e-01, -5.0611e-01],
#            [ 5.9425e-02,  6.3654e-02, -1.2069e-01,  ..., -2.6701e-01,
#             -2.6189e-01, -3.8004e-01]],
#
#           [[-2.1121e-01, -1.0430e-01, -1.6043e-01,  ..., -2.0334e-01,
#             -9.9370e-03,  6.8132e-02],
#            [-2.4360e-01, -2.3278e-01, -4.0910e-01,  ..., -3.4239e-01,
#             -1.4631e-01, -4.0353e-02],
#            [-1.6596e-02, -1.2434e-01, -4.3791e-01,  ..., -4.0788e-01,
#             -3.0355e-01, -2.0270e-01],
#            ...,
#            [ 6.8781e-03, -1.4377e-01, -4.7884e-01,  ...,  1.1735e-02,
#              2.6499e-01,  9.0721e-02],
#            [ 1.7046e-01, -1.4840e-03, -2.8923e-01,  ..., -9.5184e-03,
#              7.3879e-02, -1.3347e-01],
#            [ 8.7537e-02,  6.2893e-02, -1.3902e-01,  ...,  1.1059e-01,
#              5.4954e-02, -2.0154e-01]],
#
#           ...,
#
#           [[-2.1750e-01, -2.1283e-01, -1.7220e-01,  ...,  1.0832e-01,
#             -2.9944e-01, -5.6295e-01],
#            [-1.8124e-01, -2.6577e-01, -1.5356e-01,  ...,  1.0622e-01,
#             -3.7743e-01, -7.2332e-01],
#            [-4.5309e-02,  5.1661e-02,  8.1543e-02,  ...,  6.7681e-02,
#             -4.2817e-01, -8.2542e-01],
#            ...,
#            [-3.0397e-01, -1.8754e-01, -1.5375e-01,  ..., -3.0080e+00,
#             -3.0469e+00, -2.8134e+00],
#            [-4.8935e-01, -4.7254e-01, -3.5059e-01,  ..., -2.6163e+00,
#             -2.6388e+00, -2.5989e+00],
#            [-5.1966e-01, -5.8659e-01, -4.7028e-01,  ..., -2.4616e+00,
#             -2.3958e+00, -2.4245e+00]],
#
#           [[-5.3553e-01, -2.7081e-01, -2.9286e-01,  ..., -1.2020e-01,
#             -2.6059e-01, -6.6383e-01],
#            [-4.0524e-01, -2.5141e-01, -3.0861e-01,  ..., -1.7571e-01,
#             -2.5445e-01, -7.2922e-01],
#            [-2.5050e-01, -4.0756e-01, -4.4466e-01,  ..., -1.6404e-01,
#             -2.3912e-01, -6.0187e-01],
#            ...,
#            [-7.3309e-01, -7.7228e-01, -4.6646e-01,  ..., -3.0553e+00,
#             -2.8831e+00, -2.7023e+00],
#            [-9.0164e-01, -1.0579e+00, -8.1737e-01,  ..., -2.8135e+00,
#             -2.7261e+00, -2.6195e+00],
#            [-7.6138e-01, -8.7330e-01, -7.2427e-01,  ..., -2.4493e+00,
#             -2.5508e+00, -2.5688e+00]],
#
#           [[-5.0895e-01, -3.7712e-01, -4.6457e-01,  ..., -1.9779e-01,
#             -1.3142e-01, -3.2631e-01],
#            [-5.7325e-01, -5.5897e-01, -6.7579e-01,  ..., -4.1677e-01,
#             -3.5191e-01, -2.5106e-01],
#            [-6.9094e-01, -8.9627e-01, -9.2448e-01,  ..., -4.1315e-01,
#             -3.6116e-01, -2.9424e-01],
#            ...,
#            [-8.4050e-01, -8.9079e-01, -7.9262e-01,  ..., -2.8624e+00,
#             -2.8610e+00, -2.7974e+00],
#            [-7.9380e-01, -7.1217e-01, -6.4984e-01,  ..., -2.7392e+00,
#             -2.8505e+00, -2.8079e+00],
#            [-6.6418e-01, -5.2566e-01, -6.0324e-01,  ..., -2.6231e+00,
#             -2.7818e+00, -2.8153e+00]]],
#
#
#          [[[ 2.2013e+00,  2.4995e+00,  2.7817e+00,  ...,  2.1640e+00,
#              2.1888e+00,  2.4548e+00],
#            [ 2.0500e+00,  2.3716e+00,  2.8051e+00,  ...,  2.4783e+00,
#              2.4997e+00,  2.6851e+00],
#            [ 1.9150e+00,  2.0806e+00,  2.3123e+00,  ...,  2.8945e+00,
#              3.0781e+00,  3.1305e+00],
#            ...,
#            [-5.7756e-01, -5.1557e-01, -5.0335e-01,  ..., -6.6480e-01,
#             -4.0585e-01, -2.0493e-01],
#            [-7.2111e-01, -7.4362e-01, -7.0189e-01,  ..., -4.5649e-01,
#             -2.2201e-01, -1.8526e-02],
#            [-1.0759e+00, -1.1729e+00, -1.2367e+00,  ..., -1.8923e-01,
#             -2.7059e-01, -2.8013e-01]],
#
#           [[ 2.1610e+00,  2.4755e+00,  2.7581e+00,  ...,  2.1983e+00,
#              2.2379e+00,  2.4603e+00],
#            [ 2.0881e+00,  2.3157e+00,  2.6607e+00,  ...,  2.4152e+00,
#              2.5992e+00,  2.6549e+00],
#            [ 2.0143e+00,  2.0121e+00,  2.1465e+00,  ...,  2.8079e+00,
#              2.9215e+00,  2.7970e+00],
#            ...,
#            [-7.0532e-01, -5.3652e-01, -6.5021e-01,  ..., -4.1436e-01,
#             -2.6040e-01, -2.5040e-01],
#            [-8.7712e-01, -7.8504e-01, -7.7964e-01,  ..., -4.6702e-01,
#             -1.3623e-01,  1.3629e-01],
#            [-9.6586e-01, -1.0476e+00, -1.0844e+00,  ..., -3.1549e-01,
#             -3.2924e-01, -2.8368e-01]],
#
#           [[ 2.1146e+00,  2.2548e+00,  2.5418e+00,  ...,  2.2186e+00,
#              2.2256e+00,  2.3832e+00],
#            [ 2.1931e+00,  2.2826e+00,  2.5106e+00,  ...,  2.3254e+00,
#              2.4891e+00,  2.5055e+00],
#            [ 2.3350e+00,  2.3163e+00,  2.2348e+00,  ...,  2.5972e+00,
#              2.7241e+00,  2.6045e+00],
#            ...,
#            [-5.6624e-01, -5.6353e-01, -4.3010e-01,  ..., -3.9404e-01,
#             -2.4484e-01, -3.0879e-01],
#            [-1.0145e+00, -9.0556e-01, -8.5809e-01,  ..., -4.0874e-01,
#             -2.7365e-01,  6.6686e-04],
#            [-1.0599e+00, -9.3637e-01, -1.0863e+00,  ..., -2.2027e-01,
#             -1.8940e-01, -1.7228e-02]],
#
#           ...,
#
#           [[ 1.0688e+00,  9.4252e-01,  7.1166e-01,  ...,  2.6257e+00,
#              2.3607e+00,  2.0426e+00],
#            [ 1.0737e+00,  8.5958e-01,  7.8979e-01,  ...,  2.0382e+00,
#              1.9904e+00,  1.7740e+00],
#            [ 7.6541e-01,  6.6157e-01,  6.0788e-01,  ...,  1.8002e+00,
#              1.6359e+00,  1.5710e+00],
#            ...,
#            [ 2.1935e-01,  1.4744e-01,  9.1594e-02,  ..., -1.3358e+00,
#             -1.1852e+00, -1.0241e+00],
#            [ 1.0435e-02, -1.7251e-01, -2.0024e-01,  ..., -1.1377e+00,
#             -9.2220e-01, -7.3502e-01],
#            [-5.0159e-01, -4.9508e-01, -4.9838e-01,  ..., -1.0961e+00,
#             -9.6164e-01, -7.9171e-01]],
#
#           [[ 1.2359e+00,  1.0613e+00,  6.6702e-01,  ...,  2.4489e+00,
#              2.2375e+00,  1.9225e+00],
#            [ 1.1592e+00,  9.2705e-01,  8.5734e-01,  ...,  2.1545e+00,
#              2.0150e+00,  1.7820e+00],
#            [ 1.0741e+00,  9.3231e-01,  7.3114e-01,  ...,  1.7682e+00,
#              1.6669e+00,  1.6320e+00],
#            ...,
#            [-5.7788e-02, -1.4558e-01, -2.0169e-01,  ..., -1.0905e+00,
#             -9.7538e-01, -9.1930e-01],
#            [-2.7212e-02, -3.1016e-01, -4.2369e-01,  ..., -8.7566e-01,
#             -6.7212e-01, -5.7272e-01],
#            [-3.5723e-01, -4.3603e-01, -3.7230e-01,  ..., -8.8611e-01,
#             -7.9165e-01, -6.4312e-01]],
#
#           [[ 1.4238e+00,  1.0600e+00,  7.9196e-01,  ...,  2.2508e+00,
#              2.0624e+00,  1.8135e+00],
#            [ 1.1831e+00,  8.2294e-01,  6.7745e-01,  ...,  2.0409e+00,
#              1.9707e+00,  1.7786e+00],
#            [ 9.9688e-01,  7.6255e-01,  5.0143e-01,  ...,  1.7668e+00,
#              1.6949e+00,  1.7181e+00],
#            ...,
#            [-1.9075e-01, -4.1711e-01, -3.7797e-01,  ..., -9.0762e-01,
#             -8.6543e-01, -8.2190e-01],
#            [-2.7375e-02, -1.3625e-01, -4.0528e-01,  ..., -7.5668e-01,
#             -6.6338e-01, -5.8904e-01],
#            [-2.1163e-01, -2.8776e-01, -2.7306e-01,  ..., -5.7535e-01,
#             -5.7152e-01, -5.4640e-01]]],
#
#
#          [[[-2.5901e-01, -3.1708e-01,  1.2263e-02,  ..., -4.8995e-01,
#             -1.1803e-01,  3.4567e-01],
#            [-8.8918e-02,  1.0185e-01,  2.2816e-01,  ..., -4.9749e-01,
#              2.9014e-02,  5.8120e-01],
#            [ 1.5221e-01,  3.2104e-01,  5.7662e-01,  ..., -3.9589e-01,
#              2.2394e-01,  6.0943e-01],
#            ...,
#            [ 1.4159e+00,  1.4772e+00,  1.9017e+00,  ..., -9.6917e-01,
#             -9.2552e-01, -4.1845e-01],
#            [ 1.3789e+00,  1.5309e+00,  1.7415e+00,  ..., -7.1393e-01,
#             -6.8025e-01, -3.1384e-01],
#            [ 1.2145e+00,  1.3432e+00,  1.5038e+00,  ..., -6.9364e-01,
#             -5.5177e-01, -2.9523e-01]],
#
#           [[-6.1839e-02,  2.3880e-02,  1.2386e-01,  ..., -3.0770e-01,
#              3.6859e-02,  4.5440e-01],
#            [ 1.1738e-01,  3.4081e-01,  3.4052e-01,  ..., -2.5143e-01,
#              2.1833e-01,  5.1938e-01],
#            [ 2.5148e-01,  4.2865e-01,  6.8394e-01,  ...,  6.1635e-02,
#              3.3474e-01,  4.5964e-01],
#            ...,
#            [ 1.3850e+00,  1.5194e+00,  1.9131e+00,  ..., -1.0209e+00,
#             -9.6048e-01, -4.6527e-01],
#            [ 1.4373e+00,  1.5909e+00,  1.8945e+00,  ..., -6.8782e-01,
#             -7.6171e-01, -3.7624e-01],
#            [ 1.3233e+00,  1.3329e+00,  1.5906e+00,  ..., -6.5405e-01,
#             -5.7033e-01, -2.7342e-01]],
#
#           [[ 4.3960e-02,  6.5443e-02,  9.5887e-02,  ...,  2.0321e-02,
#              1.0615e-01,  4.8255e-01],
#            [ 1.2275e-01,  2.9537e-01,  3.6084e-01,  ...,  1.6888e-02,
#              2.4127e-01,  4.8130e-01],
#            [ 2.1514e-01,  2.8388e-01,  4.6937e-01,  ...,  3.5825e-01,
#              3.3901e-01,  4.4881e-01],
#            ...,
#            [ 1.2723e+00,  1.3430e+00,  1.9119e+00,  ..., -7.4039e-01,
#             -9.2380e-01, -8.4972e-01],
#            [ 1.3920e+00,  1.2652e+00,  1.8518e+00,  ..., -6.1362e-01,
#             -8.1050e-01, -7.3633e-01],
#            [ 1.4040e+00,  1.3679e+00,  1.2877e+00,  ..., -5.9327e-01,
#             -6.6914e-01, -4.9655e-01]],
#
#           ...,
#
#           [[-4.1695e-01, -6.8114e-01, -6.9383e-01,  ..., -1.1530e+00,
#             -1.1733e+00, -8.9521e-01],
#            [-5.6258e-01, -8.4745e-01, -8.1210e-01,  ..., -1.3212e+00,
#             -1.2844e+00, -1.1591e+00],
#            [-7.3642e-01, -9.4101e-01, -9.5302e-01,  ..., -1.4774e+00,
#             -1.3897e+00, -1.2460e+00],
#            ...,
#            [-9.3577e-01, -1.1430e+00, -1.3861e+00,  ..., -7.6719e-01,
#             -1.0139e+00, -7.5373e-01],
#            [-1.0667e+00, -1.2260e+00, -1.2964e+00,  ..., -6.4315e-01,
#             -7.8144e-01, -6.7232e-01],
#            [-1.1125e+00, -1.2092e+00, -1.2424e+00,  ..., -5.6442e-01,
#             -5.7613e-01, -6.3162e-01]],
#
#           [[-4.8188e-01, -4.8149e-01, -8.7570e-01,  ..., -1.2986e+00,
#             -1.4246e+00, -1.1795e+00],
#            [-6.2974e-01, -6.9323e-01, -1.0578e+00,  ..., -1.3427e+00,
#             -1.5741e+00, -1.4061e+00],
#            [-7.9342e-01, -8.8266e-01, -1.1405e+00,  ..., -1.5531e+00,
#             -1.6301e+00, -1.4522e+00],
#            ...,
#            [-1.0198e+00, -1.0312e+00, -1.1122e+00,  ..., -8.4762e-01,
#             -8.6219e-01, -7.1393e-01],
#            [-1.1725e+00, -1.1971e+00, -1.0781e+00,  ..., -7.3996e-01,
#             -7.5028e-01, -7.1835e-01],
#            [-1.3122e+00, -1.2066e+00, -1.0638e+00,  ..., -6.6676e-01,
#             -6.1865e-01, -7.3673e-01]],
#
#           [[-2.7234e-01, -4.6982e-01, -1.0181e+00,  ..., -1.2803e+00,
#             -1.6521e+00, -1.3982e+00],
#            [-6.1645e-01, -7.0875e-01, -1.1235e+00,  ..., -1.3302e+00,
#             -1.7949e+00, -1.6242e+00],
#            [-9.6139e-01, -1.0706e+00, -1.1445e+00,  ..., -1.4444e+00,
#             -1.8159e+00, -1.6267e+00],
#            ...,
#            [-1.1587e+00, -9.2347e-01, -8.9620e-01,  ..., -8.8129e-01,
#             -8.3619e-01, -7.6257e-01],
#            [-1.3057e+00, -1.1095e+00, -9.2545e-01,  ..., -8.2421e-01,
#             -7.6866e-01, -7.3199e-01],
#            [-1.3876e+00, -1.1272e+00, -1.0484e+00,  ..., -8.6617e-01,
#             -7.2623e-01, -7.5303e-01]]]]])

# %%
with torch.no_grad():
    init_input = backward_model(forward_target, style)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 2
#       1 with torch.no_grad():
# ----> 2     init_input = backward_model(target, style)
#
# File ~/anaconda3/envs/albert/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/search/search/map2map/map2map/models/d2d.py:56, in StyledVNet.forward(self, x, s)
#      53 y2 = self.conv_l2(x, s)
#      54 x = self.down_l2(y2, s)
# ---> 56 x = self.conv_c(x, s)
#      58 x = self.up_r2(x, s)
#      59 y2 = narrow_by(y2, 4)
#
# File ~/anaconda3/envs/albert/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/search/search/map2map/map2map/models/styled_conv.py:150, in ResStyledBlock.forward(self, x, s)
#     147     y = self.skip(y, s)
#     149 for l in self.convs:
# --> 150     x = l(x, s)
#     152 y = narrow_like(y, x)
#     153 x += y
#
# File ~/anaconda3/envs/albert/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/search/search/map2map/map2map/models/style.py:162, in ConvStyled3d.forward(self, x, s, eps)
#     160 w = w.reshape(N * C0, C1, *K3)
#     161 x = x.reshape(1, N * Cin, *DHWin)
# --> 162 x = self.conv(x, w, bias=self.bias, stride=self.stride, groups=N)
#     163 _, _, *DHWout = x.shape
#     164 x = x.reshape(N, Cout, *DHWout)
#
# RuntimeError: Calculated padded input size per channel: (1 x 1 x 1). Kernel size: (3 x 3 x 3). Kernel size can't be greater than actual input size

# %%
input = forward_dataset[0]['input']
input = input.unsqueeze(0) # add batch dimension
input.shape
# Out:
# torch.Size([1, 3, 136, 136, 136])

# %%
forward_target.shape
# Out:
# torch.Size([1, 3, 40, 40, 40])

# %%
backward_model(input, style)
# Out:
# tensor([[[[[ 2.2292e+00,  2.0011e+00,  1.9763e+00,  ...,  1.4610e+00,
#              1.3577e+00,  1.0421e+00],
#            [ 2.0884e+00,  1.9644e+00,  1.9030e+00,  ...,  1.3263e+00,
#              1.0817e+00,  7.6916e-01],
#            [ 2.0914e+00,  1.8502e+00,  1.7539e+00,  ...,  1.1005e+00,
#              1.0406e+00,  7.4730e-01],
#            ...,
#            [ 1.5845e+00,  1.7285e+00,  1.6829e+00,  ...,  1.1327e+00,
#              1.3160e+00,  1.3129e+00],
#            [ 1.5424e+00,  1.6494e+00,  1.5292e+00,  ...,  1.1559e+00,
#              1.4205e+00,  1.4900e+00],
#            [ 1.5282e+00,  1.4484e+00,  1.3947e+00,  ...,  1.0037e+00,
#              1.1947e+00,  1.3392e+00]],
#
#           [[ 2.6414e+00,  2.5797e+00,  2.0901e+00,  ...,  1.3650e+00,
#              1.2888e+00,  1.1327e+00],
#            [ 2.7372e+00,  2.5527e+00,  2.2784e+00,  ...,  9.8262e-01,
#              8.7082e-01,  8.4504e-01],
#            [ 2.4347e+00,  2.4405e+00,  2.3929e+00,  ...,  1.1357e+00,
#              9.6136e-01,  8.9343e-01],
#            ...,
#            [ 1.7628e+00,  1.6679e+00,  1.3781e+00,  ...,  9.9681e-01,
#              1.3591e+00,  1.5491e+00],
#            [ 1.4811e+00,  1.4461e+00,  1.2880e+00,  ...,  9.9267e-01,
#              1.2024e+00,  1.3217e+00],
#            [ 1.1054e+00,  1.1713e+00,  1.3167e+00,  ...,  8.1867e-01,
#              8.4672e-01,  9.7141e-01]],
#
#           [[ 2.7689e+00,  2.5585e+00,  2.0451e+00,  ...,  1.3172e+00,
#              1.2453e+00,  1.2118e+00],
#            [ 2.6293e+00,  2.5312e+00,  2.3551e+00,  ...,  1.0351e+00,
#              1.1487e+00,  1.4688e+00],
#            [ 2.2062e+00,  2.2403e+00,  2.2934e+00,  ...,  1.1206e+00,
#              1.1572e+00,  1.5238e+00],
#            ...,
#            [ 1.6558e+00,  1.3846e+00,  1.2611e+00,  ...,  1.1965e+00,
#              1.2328e+00,  1.4430e+00],
#            [ 1.2983e+00,  1.1887e+00,  1.2948e+00,  ...,  1.3403e+00,
#              1.2900e+00,  1.2176e+00],
#            [ 8.1318e-01,  8.1037e-01,  1.1463e+00,  ...,  1.2606e+00,
#              1.0291e+00,  9.2440e-01]],
#
#           ...,
#
#           [[-7.0472e-01, -8.1619e-01, -1.0519e+00,  ..., -2.5757e+00,
#             -2.1808e+00, -1.7598e+00],
#            [-4.2722e-01, -6.8861e-01, -1.2432e+00,  ..., -3.5195e+00,
#             -3.1013e+00, -2.2337e+00],
#            [-2.4197e-01, -5.8071e-01, -9.4777e-01,  ..., -3.9075e+00,
#             -3.1435e+00, -2.5733e+00],
#            ...,
#            [ 3.5317e-01,  4.5153e-01,  2.7952e-01,  ...,  2.2254e-01,
#              3.3551e-01,  5.6285e-01],
#            [ 3.0249e-01,  5.0728e-01,  4.5951e-01,  ...,  4.2842e-01,
#              5.3818e-01,  5.8616e-01],
#            [ 2.8596e-01,  4.4374e-01,  3.1568e-01,  ...,  4.9664e-01,
#              3.5683e-01,  4.4035e-01]],
#
#           [[-1.0670e+00, -1.3177e+00, -1.4704e+00,  ..., -3.6723e+00,
#             -2.8470e+00, -2.1683e+00],
#            [-8.3869e-01, -9.1344e-01, -1.1051e+00,  ..., -4.0957e+00,
#             -3.3774e+00, -2.5440e+00],
#            [-3.7087e-01, -5.9148e-01, -8.0744e-01,  ..., -4.3682e+00,
#             -3.4876e+00, -2.7627e+00],
#            ...,
#            [ 5.7624e-01,  1.9575e-01, -1.8198e-01,  ...,  4.1065e-01,
#              4.8285e-01,  4.3193e-01],
#            [ 3.8817e-01,  2.2540e-01, -3.3832e-04,  ...,  5.3934e-01,
#              5.2411e-01,  6.9079e-01],
#            [ 1.4846e-01,  2.8144e-01,  2.6346e-01,  ...,  4.7600e-01,
#              4.6013e-01,  6.5944e-01]],
#
#           [[-6.7208e-01, -7.4783e-01, -8.8337e-01,  ..., -3.9999e+00,
#             -3.7952e+00, -2.9685e+00],
#            [-7.4748e-01, -7.7412e-01, -6.2372e-01,  ..., -3.9089e+00,
#             -3.9058e+00, -2.9726e+00],
#            [-3.6399e-01, -4.1115e-01, -1.0008e-01,  ..., -3.7479e+00,
#             -3.5677e+00, -2.7148e+00],
#            ...,
#            [ 4.7159e-01,  5.7361e-02, -1.9312e-01,  ...,  1.8596e-01,
#              1.7396e-01,  2.3267e-02],
#            [ 2.3427e-01, -3.5801e-02, -1.4260e-01,  ...,  3.9648e-01,
#              3.7914e-01,  4.3308e-01],
#            [ 7.1863e-02, -2.4475e-02, -9.0467e-03,  ...,  3.6538e-01,
#              3.2258e-01,  4.6748e-01]]],
#
#
#          [[[ 1.0987e-01, -2.5913e-02, -2.2819e-01,  ...,  9.1236e-01,
#              5.0588e-01,  2.4346e-01],
#            [ 7.5846e-01,  5.5695e-01,  3.7094e-02,  ...,  3.0148e-01,
#              2.1675e-01,  9.4953e-02],
#            [ 9.9067e-01,  9.3574e-01,  5.6435e-01,  ..., -9.2645e-02,
#              9.7903e-02,  1.9609e-01],
#            ...,
#            [-8.7517e-01, -1.0730e+00, -1.2246e+00,  ...,  6.8230e-01,
#              5.2413e-01,  4.6630e-01],
#            [-6.8713e-01, -1.0207e+00, -1.3796e+00,  ...,  5.4971e-01,
#              7.2915e-01,  7.7787e-01],
#            [-7.5329e-01, -8.5965e-01, -1.3406e+00,  ...,  4.3261e-01,
#              7.1119e-01,  9.2611e-01]],
#
#           [[ 2.2522e-01,  3.0632e-02, -2.1487e-01,  ...,  6.1661e-01,
#              2.2666e-01,  5.5370e-02],
#            [ 9.5536e-01,  7.1134e-01,  1.8885e-01,  ...,  2.4065e-01,
#             -6.6679e-02, -2.0136e-01],
#            [ 8.0341e-01,  7.0763e-01,  6.6187e-01,  ..., -7.2987e-02,
#              3.8846e-01,  5.6599e-01],
#            ...,
#            [-1.0116e+00, -1.3583e+00, -1.5329e+00,  ...,  4.3343e-01,
#              3.5393e-01,  1.6093e-01],
#            [-8.7511e-01, -1.2138e+00, -1.5430e+00,  ...,  1.7070e-01,
#              3.8072e-01,  5.7900e-01],
#            [-7.9029e-01, -1.0707e+00, -1.4461e+00,  ...,  2.7202e-02,
#              5.0511e-01,  6.1625e-01]],
#
#           [[ 5.3572e-01,  2.2163e-01,  3.2247e-02,  ...,  8.6519e-02,
#             -1.5908e-01, -1.2417e-01],
#            [ 8.4008e-01,  6.7448e-01,  4.8727e-01,  ...,  2.1997e-01,
#             -7.0732e-02, -3.5228e-02],
#            [ 4.4042e-01,  4.8828e-01,  5.1794e-01,  ...,  1.1554e-01,
#              4.4120e-01,  6.0212e-01],
#            ...,
#            [-1.3590e+00, -1.7226e+00, -1.6733e+00,  ...,  3.2549e-01,
#             -9.7659e-03, -1.9291e-01],
#            [-1.4021e+00, -1.5324e+00, -1.4907e+00,  ..., -2.6217e-02,
#             -8.3521e-02,  7.7444e-02],
#            [-1.1410e+00, -1.4634e+00, -1.6350e+00,  ..., -4.6868e-03,
#              2.2140e-01,  4.0131e-01]],
#
#           ...,
#
#           [[-1.4611e+00, -1.5882e+00, -1.8460e+00,  ..., -1.7895e+00,
#             -2.1211e+00, -1.7827e+00],
#            [-1.5879e+00, -1.6789e+00, -1.7709e+00,  ..., -1.8314e+00,
#             -1.6948e+00, -1.6277e+00],
#            [-1.7275e+00, -1.6188e+00, -1.2414e+00,  ..., -2.1998e+00,
#             -2.0917e+00, -1.5176e+00],
#            ...,
#            [-1.5279e+00, -1.5832e+00, -1.7675e+00,  ...,  2.0903e-02,
#              9.5292e-03,  1.3987e-01],
#            [-1.1333e+00, -1.4445e+00, -1.8756e+00,  ..., -3.4848e-01,
#             -4.9159e-02,  8.0500e-02],
#            [-1.3744e+00, -1.6419e+00, -2.0178e+00,  ..., -5.5502e-01,
#             -2.5762e-01, -1.8342e-01]],
#
#           [[-1.3217e+00, -1.3901e+00, -1.7761e+00,  ..., -2.7646e+00,
#             -2.6412e+00, -2.2561e+00],
#            [-1.2680e+00, -1.4959e+00, -1.9136e+00,  ..., -2.5823e+00,
#             -2.4765e+00, -1.9464e+00],
#            [-1.4181e+00, -1.3933e+00, -8.2846e-01,  ..., -2.6507e+00,
#             -2.2671e+00, -2.0041e+00],
#            ...,
#            [-1.4416e+00, -1.4070e+00, -1.5555e+00,  ..., -6.5126e-02,
#              8.2585e-02,  4.2723e-01],
#            [-1.2163e+00, -1.3851e+00, -1.6615e+00,  ..., -1.4878e-01,
#             -1.8909e-02,  1.5598e-01],
#            [-1.4679e+00, -1.7647e+00, -2.1620e+00,  ..., -6.2211e-01,
#             -4.5594e-01, -1.3757e-01]],
#
#           [[-1.4774e+00, -1.4587e+00, -1.6819e+00,  ..., -2.8851e+00,
#             -3.0862e+00, -2.4230e+00],
#            [-1.2127e+00, -1.3930e+00, -1.5657e+00,  ..., -2.8911e+00,
#             -2.6887e+00, -2.3423e+00],
#            [-9.0710e-01, -9.4027e-01, -6.1026e-01,  ..., -2.8643e+00,
#             -2.5274e+00, -2.1744e+00],
#            ...,
#            [-1.4484e+00, -1.3619e+00, -1.4527e+00,  ...,  3.2285e-02,
#              2.2921e-01,  6.5084e-01],
#            [-1.4119e+00, -1.3314e+00, -1.3840e+00,  ..., -7.2705e-02,
#              1.1089e-01,  3.2492e-01],
#            [-1.5838e+00, -1.7157e+00, -1.8815e+00,  ..., -5.4367e-01,
#             -5.0729e-01, -3.6523e-01]]],
#
#
#          [[[-4.0532e-02,  8.3905e-01,  1.4610e+00,  ...,  6.3751e-01,
#              7.2997e-01,  6.2255e-01],
#            [-1.5021e-01,  6.8277e-01,  1.0407e+00,  ...,  4.6082e-01,
#              4.2526e-01,  5.1559e-01],
#            [-1.5636e-01,  3.3522e-01,  6.6279e-01,  ...,  5.5013e-01,
#              4.2046e-01,  4.5785e-01],
#            ...,
#            [-2.3618e-01, -4.5455e-02,  1.4587e-01,  ...,  3.9606e+00,
#              3.7264e+00,  3.6640e+00],
#            [-4.4077e-01, -3.2332e-01, -4.9541e-03,  ...,  3.6433e+00,
#              3.7496e+00,  3.6623e+00],
#            [-6.1641e-01, -7.1227e-01, -4.7186e-01,  ...,  4.0057e+00,
#              4.0253e+00,  3.8601e+00]],
#
#           [[-1.3856e-02,  7.0369e-01,  1.2669e+00,  ...,  6.8195e-01,
#              6.0426e-01,  5.0216e-01],
#            [ 3.2811e-03,  3.9763e-01,  9.5669e-01,  ...,  3.7141e-01,
#              1.9224e-01,  4.3134e-01],
#            [-1.2131e-01,  1.6911e-01,  6.4239e-01,  ...,  6.0999e-01,
#              2.0028e-01,  4.6061e-01],
#            ...,
#            [-1.5769e-01, -5.5197e-02, -6.4996e-02,  ...,  3.8471e+00,
#              3.8484e+00,  3.4991e+00],
#            [-4.8696e-01, -2.9346e-01, -2.3224e-01,  ...,  3.8657e+00,
#              3.9986e+00,  3.9613e+00],
#            [-7.2741e-01, -6.7629e-01, -4.7401e-01,  ...,  3.6542e+00,
#              3.9519e+00,  3.7324e+00]],
#
#           [[ 6.1554e-02,  4.3493e-01,  6.5452e-01,  ...,  5.2956e-01,
#              6.2649e-01,  2.7483e-01],
#            [-5.5380e-02,  1.9361e-01,  6.9790e-01,  ...,  4.5551e-01,
#              3.1486e-01,  5.8237e-01],
#            [-3.7093e-02,  1.4146e-01,  5.3454e-01,  ...,  6.8577e-01,
#              2.9655e-01,  7.3244e-01],
#            ...,
#            [-3.2402e-01, -2.6497e-01, -3.1959e-01,  ...,  4.2658e+00,
#              4.2868e+00,  3.8111e+00],
#            [-7.2099e-01, -2.7524e-01, -3.1094e-01,  ...,  3.8835e+00,
#              4.1182e+00,  3.9641e+00],
#            [-1.0946e+00, -4.1912e-01, -3.5557e-01,  ...,  3.9174e+00,
#              4.2949e+00,  4.1730e+00]],
#
#           ...,
#
#           [[ 2.2277e-01,  4.3628e-01,  5.5701e-01,  ...,  3.5717e+00,
#              5.1991e+00,  4.4605e+00],
#            [ 1.3258e-01,  3.3702e-01,  3.3857e-01,  ...,  3.5201e+00,
#              4.7308e+00,  3.6898e+00],
#            [ 6.6769e-02,  5.5923e-01,  6.3347e-01,  ...,  3.8783e+00,
#              4.7541e+00,  3.6352e+00],
#            ...,
#            [ 1.7958e+00,  1.8684e+00,  1.4345e+00,  ...,  2.5001e+00,
#              2.6437e+00,  2.3332e+00],
#            [ 1.7711e+00,  1.6076e+00,  1.4574e+00,  ...,  2.5123e+00,
#              2.4232e+00,  2.4418e+00],
#            [ 1.4741e+00,  1.2440e+00,  1.2948e+00,  ...,  2.2987e+00,
#              2.2704e+00,  2.1251e+00]],
#
#           [[ 6.1172e-02,  2.4046e-01,  5.2329e-01,  ...,  3.5887e+00,
#              5.7148e+00,  4.5736e+00],
#            [-1.5222e-02,  7.9008e-02,  1.3539e-01,  ...,  4.0619e+00,
#              5.1887e+00,  4.4340e+00],
#            [-5.4381e-02,  1.8223e-01,  4.5399e-01,  ...,  3.9450e+00,
#              5.4534e+00,  3.8069e+00],
#            ...,
#            [ 1.9047e+00,  1.7420e+00,  1.2947e+00,  ...,  2.9664e+00,
#              2.8739e+00,  2.7683e+00],
#            [ 1.9756e+00,  1.6218e+00,  1.3550e+00,  ...,  2.8066e+00,
#              2.7023e+00,  2.6163e+00],
#            [ 1.6856e+00,  1.4413e+00,  1.2222e+00,  ...,  2.5524e+00,
#              2.5955e+00,  2.5599e+00]],
#
#           [[-2.4231e-02,  1.3022e-01,  5.9710e-01,  ...,  3.7338e+00,
#              5.7840e+00,  5.0672e+00],
#            [-1.3890e-01,  2.0276e-01,  2.6451e-01,  ...,  3.5119e+00,
#              5.5067e+00,  4.4824e+00],
#            [-1.6434e-01,  1.8407e-01,  6.5444e-01,  ...,  4.1466e+00,
#              5.6340e+00,  4.3135e+00],
#            ...,
#            [ 1.5540e+00,  1.3664e+00,  1.1629e+00,  ...,  3.0249e+00,
#              2.9660e+00,  2.5698e+00],
#            [ 1.7082e+00,  1.4624e+00,  1.2052e+00,  ...,  3.0530e+00,
#              2.9582e+00,  2.8697e+00],
#            [ 1.6348e+00,  1.5209e+00,  1.2185e+00,  ...,  2.6797e+00,
#              2.8589e+00,  2.6053e+00]]]]], grad_fn=<AsStridedBackward0>)

# %%
from map2map.map2map.models import StyledVNet
from map2map.map2map.utils import load_model_state_dict

model: StyledVNet = StyledVNet(
    style_size=args.style_size,
    in_chan=sum(args.in_chan),
    out_chan=sum(args.out_chan),
    dropout_prob=args.dropout_prob,
)
model.to(device)

state = torch.load("../model_weights/backward_model.pt", map_location=device)
load_model_state_dict(model, state["model"], strict=True)

# %%
backward_model = model
backward_model(forward_target, style)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 2
#       1 backward_model = model
# ----> 2 backward_model(target, style)
#
# File ~/anaconda3/envs/albert/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/search/search/map2map/map2map/models/d2d.py:56, in StyledVNet.forward(self, x, s)
#      53 y2 = self.conv_l2(x, s)
#      54 x = self.down_l2(y2, s)
# ---> 56 x = self.conv_c(x, s)
#      58 x = self.up_r2(x, s)
#      59 y2 = narrow_by(y2, 4)
#
# File ~/anaconda3/envs/albert/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/search/search/map2map/map2map/models/styled_conv.py:150, in ResStyledBlock.forward(self, x, s)
#     147     y = self.skip(y, s)
#     149 for l in self.convs:
# --> 150     x = l(x, s)
#     152 y = narrow_like(y, x)
#     153 x += y
#
# File ~/anaconda3/envs/albert/lib/python3.9/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/search/search/map2map/map2map/models/style.py:162, in ConvStyled3d.forward(self, x, s, eps)
#     160 w = w.reshape(N * C0, C1, *K3)
#     161 x = x.reshape(1, N * Cin, *DHWin)
# --> 162 x = self.conv(x, w, bias=self.bias, stride=self.stride, groups=N)
#     163 _, _, *DHWout = x.shape
#     164 x = x.reshape(N, Cout, *DHWout)
#
# RuntimeError: Calculated padded input size per channel: (1 x 1 x 1). Kernel size: (3 x 3 x 3). Kernel size can't be greater than actual input size

# %%
from map2map.map2map.data.fields import FieldDataset

dataset = FieldDataset(
    style_pattern=args.style_path,
    in_patterns=[args.init_input_path],
    tgt_patterns=[args.target_output_path],
    in_norms=['cosmology.dis'],
    tgt_norms=None,
    callback_at='/home/ajliang/search/search/map2map',
    augment=True,
    aug_shift=16,
    aug_add=None,
    aug_mul=None,
    crop=40,
    crop_start=None,
    crop_stop=None,
    crop_step=40,
    in_pad=48,
    tgt_pad=0,
    scale_factor=1
)

# %%
backward_model = model
backward_model()
